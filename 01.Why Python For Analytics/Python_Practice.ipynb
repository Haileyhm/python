# %%
pwd
# Out:
# 'C:\\Users\\SMART-01\\Python_Fintech'

# %%
import numpy as np

# %%
np.linspace
# Out:
# <function numpy.core.function_base.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)>

# %%
np.random.random(size=10)*1000
# Out:
# array([249.07100432, 808.79933817, 249.46810956, 683.73050716,
#        876.16704246, 808.09938517, 125.82456727, 132.57066664,
#        384.19633491, 716.64713245])

# %%
import pandas as pd
from itertools import repeat
a=["A01","A02","A03"]

b=["201501","201502","201503"]
c=["100","150",None,"200"]
my

pd.read_csv("C:/Users/SMART-01/Python_Fintech/kopo_product_volume.csv",encoding="ms949")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-328989188ab6> in <module>
#       4 b=["201501","201502","201503"]
#       5 c=["100","150",None,"200"]
# ----> 6 my
#
# NameError: name 'my' is not defined

# %%
pd.read_csv("C:/Users/SMART-01/Python_Fintech/kopo_product_volume.csv",encoding="ms949")
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME  이동평균(판매추세량) 15         변동률 9  \
# 0        A01       ST0001    201501   513598     509442.0000   2904.314794
# 1        A01       ST0001    201502   438251     516120.1111   3010.428137
# 2        A01       ST0001    201503   420290     515676.0000   4371.071109
# 3        A01       ST0001    201504   458431     516504.2727   6032.104522
# 4        A01       ST0001    201505   482381     514004.6667  10856.747410
# 5        A01       ST0001    201506   570412     510622.7692  17230.602410
# 6        A01       ST0001    201507   620392     504735.0714  24419.458070
# 7        A01       ST0001    201508   571781     525095.6667  31118.702550
# 8        A01       ST0001    201509   569545     541850.9333  36402.672160
# 9        A01       ST0001    201510   511679     559134.3333  38637.601200
# 10       A01       ST0001    201511   524787     575879.2667  37054.983600
# ...

# %%
pd.read_csv("./kopo_product_volume.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-50-6e20b69bf95d> in <module>
# ----> 1 pd.read_csv("./kopo_product_volume.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
# ...

# %%
import matplotlib

font_name = matplotlib.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
matplotlib.rc('font', family=font_name)
print(font_name)
# Out:
# Malgun Gothic

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
x=np.linspace(1,20,2)
y=x**2
plt.plot(x,y)
plt.title("샘플차트")
# Out:
# Text(0.5, 1.0, '샘플차트')

# %%
import matplotlib

font_name=matplotlib

# %%
pd.read_csv("C:\Users\SMART-01\Python_Fintech/kopo_")
